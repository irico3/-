# %%
## 2-1

# %%
from vector_drawing import *
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)
]

draw(
    Points(*dino_vectors),
    Segment((6,4),(3,1))
)

# %%
draw(
    Points((2, -2)),
    Arrow((2,-2))
)

# %%
draw(
    Points(*dino_vectors),
    Polygon(*dino_vectors)
)

# %%
draw(
    Points(*[(x,x**2) for x in range(-10, 11)]),
    grid=(1,10),
    nice_aspect_ratio=False
)

# %%
## 2-2
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
def add(v1, v2):
    return (v1[0] + v2[0], v1[1] + v2[1])

# %%
dino_vectors2 = [add((-1.5,-2.5), v) for v in dino_vectors]

# %%
draw(
    Points(*dino_vectors, color=blue),
    Polygon(*dino_vectors, color=blue),
    Points(*dino_vectors2, color=red),
    Polygon(*dino_vectors2, color=red)
)

# %%
from math import sqrt
def length(v):
    return sqrt(v[0]**2 +v[1]**2)

# %%
draw(
    Points((2,2),(-1,3)),
    Segment((2,2),(-1,3), color=red)
)

# %% [markdown]
# u=(-2,0) v=(1.5,1.5) w=(4,1)
# - u+v = (-0.5, 1.5)
# - v+w = (5.5, 2.5)
# - u+w = (2, 1)
# - u+v+w = (3.5, 2.5)

# %%
def add(*vectors):
    return (sum(v[0] for v in vectors)), (sum(v[1] for v in vectors))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 max(dino_vectors, key=length)
#
# Cell In[25], line 3, in length(v)
#       2 def length(v):
# ----> 3     return sqrt(v[0]**2, v[1]**2)
#
# TypeError: math.sqrt() takes exactly one argument (2 given)

# %%
def translate(translation, vectors):
    return [add(translation, v) for v in vectors]

translate((1,1), [(0,0), (0,1,), (-3,-3)])

def hundred_dinos():
    translations = [(12*x,10*y) 
                    for x in range(-5,5) 
                    for y in range(-5,5)]
    dinos = [Polygon(*translate(t, dino_vectors),color=blue)
                for t in translations]
    draw(*dinos, grid=None, axes=None, origin=None)

hundred_dinos()

# %%
from math import sqrt, pi
draw(
    Points((sqrt(2),sqrt(3))),
    Arrow((sqrt(2),sqrt(3))),
    Arrow((sqrt(2) * pi ,sqrt(3) * pi),(sqrt(2),sqrt(3)))
)

# %%
def scale(scalar, v):
    return (v[0] * scalar, v[1] * scalar)

# %%
rs_set = [(r,s) for r in range(-3, 4) for s in range(-1, 2)]
u = (-1,1)
v = (1, 1)

allPoints = [add(scale(r, u), scale(s, v)) for (r,s) in rs_set]

print(allPoints)

draw(
    Points(*allPoints)
)
# Out:
# [(2, -4), (3, -3), (4, -2), (1, -3), (2, -2), (3, -1), (0, -2), (1, -1), (2, 0), (-1, -1), (0, 0), (1, 1), (-2, 0), (-1, 1), (0, 2), (-3, 1), (-2, 2), (-1, 3), (-4, 2), (-3, 3), (-2, 4)]

# %%
def subtract(v1,v2):
    return (v1[0] - v2[0], v1[1] - v2[1])

# %%
def distance(v1, v2):
    return length(subtract(v1, v2))

# %%
def perimeter(vectors):
    distances = [
        distance(vectors[i], vectors[(i + 1) % len(vectors)])
        for i in range(0, len(vectors))
    ]
    return sum(distances)

# %%
perimeter([(1,0), (1,1), (0,1), (0,0)])
# Out:
# 4.0

# %%
for n in range(0, 15):
    for m in range(0, 13):
        if distance((n,m), (1,-1)) == 13 and n > m:
            print((n,m))
# Out:
# (13, 4)

# %% [markdown]
# ## 2-3 三角関数

# %%
from math import sin, cos
def to_cartesian(polar_vector):
    (length, angle) = polar_vector
    return (length * cos(angle), length * sin(angle))

# %%
from math import pi
angle = 37 *
